# %% [markdown]
# ### 清洗数据

# %%
import pandas as pd
# 读取 Excel 文件（支持 .xlsx 和 .xls）
df = pd.read_excel("./基本信息整理.xlsx", sheet_name="基本信息")  # 可指定工作表
df
# Out:
#       区划名称    地区层级             上级区划名称                                  主项名称  \
# 0      长春市      市级                吉林省            对在档案工作中做出显著成绩的单位和个人的表彰或者奖励
# 1      长春市      市级                吉林省                      对重点建设项目（工程）档案的验收
# 2      长春市      市级                吉林省                         加工贸易项下光盘进出口审批
# 3      长春市      市级                吉林省  音像复制单位、电子出版物复制单位接收委托复制境外音像制品、电子出版物许可
# 4      长春市      市级                吉林省                           非法、违禁出版物的鉴定
# ...    ...     ...                ...                                   ...
# 35877  太平村  村（社区）级  双城堡镇,公主岭市,长春市,吉林省                                就业信息服务
# 35878  兴城村  村（社区）级  双城堡镇,公主岭市,长春市,吉林省                                就业信息服务
# 35879  兴城村  村（社区）级  双城堡镇,公主岭市,长春市,吉林省                            计划生育政策咨询服务
# 35880  兴城村  村（社区）级  双城堡镇,公主岭市,长春市,吉林省                      职业介绍、职业指导和创业开业指导
# 35881  房家村  村（社区）级    弓棚镇,榆树市,长春市,吉林省                      职业介绍、职业指导和创业开业指导
#
#            子项名称                               业务办理项名称  承诺办结时限 是否收费  \
# 0           NaN            对在档案工作中做出显著成绩的单位和个人的表彰或者奖励     1.0    否
# 1           NaN                      对重点建设项目（工程）档案的验收    10.0    否
# 2           NaN                         加工贸易项下光盘进出口审批     1.0    否
# 3           NaN  音像复制单位、电子出版物复制单位接收委托复制境外音像制品、电子出版物许可    10.0    否
# 4           NaN                       非法、违禁出版物的鉴定（非法）     3.0    否
# ...         ...                                   ...     ...  ...
# 35877  就业政策法规咨询                              就业政策法规咨询     1.0    否
# 35878  就业政策法规咨询                              就业政策法规咨询     1.0    否
# 35879       NaN                            计划生育政策咨询服务     1.0    否
# 35880      职业介绍                                  职业介绍     1.0    否
# 35881      职业介绍                                  职业介绍     1.0    否
#
#                                                     受理条件  \
# 0      对档案的收集、整理、提供利用做出显著成绩的；对档案的保护和现代化管理做出显著成绩的；对档案学...
# 1      项目主体工程和辅助设施已按照设计建成，能满足生产或使用的需要;项目试运行指标考核合格或者达到...
# 2      1. 申请单位须是依法批准设立的企业； \n2. 进出口光盘不得载有法律、法规禁载的内容；\...
# 3      1、有音像、电子出版物复制单位的名称、章程 2、承接复制的必须是依法设立的复制单位 3、委托...
# 4                         1.有申请鉴定的正当理由2.鉴定物品为出版物（含电子出版物）
# ...                                                  ...
# 35877                                通过省人社厅网站或12333电话咨询。
# 35878                                通过省人社厅网站或12333电话咨询。
# 35879                                                  无
# 35880                                     通过人社网站、电话或窗口咨询
# 35881                                     通过人社网站、电话或窗口咨询
#
#                                     办理地点  \
# 0      吉林省长春市南关区明珠街道华新街700号长春市政务服务中心综合窗口
# 1      吉林省长春市南关区明珠街道华新街700号长春市政务服务中心综合窗口
# 2      吉林省长春市南关区明珠街道华新街700号长春市政务服务中心综合窗口
# 3      吉林省长春市南关区明珠街道华新街700号长春市政务服务中心综合窗口
# 4              长春市南关区人民大街10111号3楼0310办公室
# ...                                  ...
# 35877             吉林省长春市公主岭市双城堡镇太平村便民服务站
# 35878             吉林省长春市公主岭市双城堡镇兴城村便民服务站
# 35879             吉林省长春市公主岭市双城堡镇兴城村便民服务站
# 35880             吉林省长春市公主岭市双城堡镇兴城村便民服务站
# 35881           吉林省长春市榆树市弓棚镇房家村便民服务站综合窗口
#
#                                                     办理时间           咨询方式  \
# 0      春夏季：星期一至星期五09：00-17：00（法定节假日除外，中午不间断服务）\n秋冬季：星...  0431-88776051
# 1      春夏季：星期一至星期五09：00-17：00（法定节假日除外，中午不间断服务）\n秋冬季：星...  0431-88776051
# 2      春夏季：星期一至星期五09：00-17：00（法定节假日除外，中午不间断服务）  秋冬季：星...  0431-88776228
# 3      春夏季：星期一至星期五09：00-17：00（法定节假日除外，中午不间断服务） \n秋冬季：...  0431-88776228
# 4      法定工作日\n上午08:00——11:30\n下午（夏）13:30——17:00\n下午（冬...  0431-88776241
# ...                                                  ...            ...
# 35877  春夏季：星期一至星期五：8：30-16：30（法定节假日除外，中午不间断服务）\n秋冬季：星...  0431-76710020
# 35878  春夏季：星期一至星期五：8：30-16：30（法定节假日除外，中午不间断服务）\n秋冬季：星...  0431-76710020
# 35879  春夏季：星期一至星期五：8：30-16：30（法定节假日除外，中午不间断服务）\n秋冬季：星...  0431-76710020
# 35880  春夏季：星期一至星期五：8：30-16：30（法定节假日除外，中午不间断服务）\n秋冬季：星...  0431-76710020
# 35881  春夏季：星期一至星期五8:30-16:30（法定节假日除外，中午不间断服务）\n秋冬季：星期...  0431-83788019
#
#                                                     材料名称   情形
# 0                  捐赠突出贡献个人审批表^捐赠突出贡献单位审批表^个人捐赠或单位捐赠事迹材料  NaN
# 1                                       档案验收申请报告^档案验收申请表  NaN
# 2      著作权人证明^进出口申请报告^样品及审读报告（赴境外加工光盘进口备案证明）^复制单位许可证^...  NaN
# 3      复制企业的音像制品复制许可证^委托企业、复制企业的经办人居民身份证^营业执照副本^委托复制产...  NaN
# 4                  申请人身份证明^鉴定申请书^申请鉴定的出版物来源证明材料^申请鉴定的出版物  NaN
# ...                                                  ...  ...
# 35877                                                NaN  NaN
# 35878                                                NaN  NaN
# 35879                                                NaN  NaN
# 35880                                                身份证  NaN
# 35881                                                身份证  NaN
#
# [35882 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35882 entries, 0 to 35881
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   区划名称     35882 non-null  object
#  1   地区层级     35882 non-null  object
#  2   上级区划名称   35882 non-null  object
#  3   主项名称     35882 non-null  object
#  4   子项名称     14574 non-null  object
#  5   业务办理项名称  35882 non-null  object
#  6   承诺办结时限   35876 non-null  float64
#  7   是否收费     35882 non-null  object
#  8   受理条件     34608 non-null  object
#  9   办理地点     34608 non-null  object
#  10  办理时间     34608 non-null  object
#  11  咨询方式     35882 non-null  object
#  12  材料名称     30107 non-null  object
#  13  情形       2850 non-null   object
# dtypes: float64(1), object(13)
# memory usage: 3.8+ MB

# %%
# 标记所有重复行
duplicates = df.duplicated(keep=False)  # keep=False 标记所有重复项
print("重复行：")
print(df[duplicates])
# Out:
# 重复行：
# Empty DataFrame
# Columns: [区划名称, 地区层级, 上级区划名称, 主项名称, 子项名称, 业务办理项名称, 承诺办结时限, 是否收费, 受理条件, 办理地点, 办理时间, 咨询方式, 材料名称, 情形]
# Index: []

# %%
# 统计每列的缺失值数量
# import matplotlib.pyplot as plt
missing_values = df.isnull().sum()
print("缺失值统计：")
print(missing_values)

# 可视化缺失值（需安装 matplotlib）
# missing_values.plot(kind='bar', title='缺失值分布')
# plt.show()
# Out:
# 缺失值统计：
# 区划名称           0
# 地区层级           0
# 上级区划名称         0
# 主项名称           0
# 子项名称       21308
# 业务办理项名称        0
# 承诺办结时限         6
# 是否收费           0
# 受理条件        1274
# 办理地点        1274
# 办理时间        1274
# 咨询方式           0
# 材料名称        5775
# 情形         33032
# dtype: int64

# %% [markdown]
# ### 电话号码校验

# %%
# 使用 str.match() 匹配正则表达式
pattern = r'^\d{4}-\d{8}$|^\d{11}$'  # 合法格式的正则
df["是否合法"] = df["咨询方式"].str.match(pattern)

# 筛选出不合法的记录
invalid_phones = df[~df["是否合法"]]
invalid_phones
# Out:
#         区划名称    地区层级             上级区划名称              主项名称      子项名称  \
# 16       长春市      市级                吉林省    事业单位设立、变更、注销登记       NaN
# 17       长春市      市级                吉林省    事业单位设立、变更、注销登记       NaN
# 18       长春市      市级                吉林省    事业单位设立、变更、注销登记       NaN
# 19       长春市      市级                吉林省    事业单位设立、变更、注销登记       NaN
# 20       长春市      市级                吉林省    事业单位设立、变更、注销登记       NaN
# ...      ...     ...                ...               ...       ...
# 35095  永宁路社区  村（社区）级   长通街道,南关区,长春市,吉林省  职业介绍、职业指导和创业开业指导      职业指导
# 35193   八家子村  村（社区）级    同太乡,德惠市,长春市,吉林省            就业信息服务  就业政策法规咨询
# 35370   新荣社区  村（社区）级   新隆街道,宽城区,长春市,吉林省        计划生育政策咨询服务       NaN
# 35546   育才社区  村（社区）级   建设街道,德惠市,长春市,吉林省            就业信息服务  就业政策法规咨询
# 35867    红旗村  村（社区）级  双城堡镇,公主岭市,长春市,吉林省  职业介绍、职业指导和创业开业指导      职业介绍
#
#                  业务办理项名称  承诺办结时限 是否收费  \
# 16            事业单位法人证书补领     1.0    否
# 17     事业单位变更登记（变更法定代表人）     1.0    否
# 18      事业单位变更登记（变更开办资金）     1.0    否
# 19              事业单位设立登记     1.0    否
# 20      事业单位变更登记（变更经费来源）     1.0    否
# ...                  ...     ...  ...
# 35095               职业指导    33.0    否
# 35193        高校毕业生就业政策咨询     1.0    否
# 35370         计划生育政策咨询服务     1.0    否
# 35546           就业政策法规咨询     1.0    否
# 35867               职业介绍     1.0    否
#
#                                                     受理条件  \
# 16     第六十三条 事业单位遗失或者损毁《事业单位法人证书》的，应当向登记管理机关申请补（换）领。\...
# 17     第四十五条 事业单位的登记事项需要变更的，应当向登记管理机关申请变更登记。\n　　变更名称、...
# 18     第四十五条 事业单位的登记事项需要变更的，应当向登记管理机关申请变更登记。\n　　变更名称、...
# 19     第三十六条 申请事业单位法人设立登记的单位，应当具备下列条件：\n　　（一）经审批机关批准设...
# 20     第四十五条 事业单位的登记事项需要变更的，应当向登记管理机关申请变更登记。\n　　变更名称、...
# ...                                                  ...
# 35095                                       通过网站、电话或窗口咨询
# 35193                                       到窗口直接咨询或电话咨询
# 35370                                                  无
# 35546                                通过省人社厅网站或12333电话咨询。
# 35867                                     通过人社网站、电话或窗口咨询
#
#                                                     办理地点  \
# 16     吉林省长春市南关区明珠街道南环城路3066号长春市政府第二办公区A311；吉林省长春市南关区...
# 17     吉林省长春市南关区明珠街道南环城路3066号长春市政府第二办公区A311；吉林省长春市南关区...
# 18     吉林省长春市南关区明珠街道南环城路3066号长春市政府第二办公区A311；吉林省长春市南关区...
# 19     吉林省长春市南关区明珠街道南环城路3066号长春市政府第二办公区A311；吉林省长春市南关区...
# 20     吉林省长春市南关区明珠街道南环城路3066号长春市政府第二办公区A311；吉林省长春市南关区...
# ...                                                  ...
# 35095                             长春市南关区东湾半岛四区13栋永宁路社区2楼
# 35193                          吉林省长春市德惠市同太乡八家子村便民服务站综合窗口
# 35370         吉林省长春市宽城区新隆街道新荣社区基隆北街与扶余路交汇处基隆小区东门10栋101门市
# 35546                 吉林省长春市德惠市育才街与惠泽路交汇德惠市育才社区便民服务站综合窗口
# 35867                             吉林省长春市公主岭市双城堡镇红旗村便民服务站
#
#                                                     办理时间  \
# 16     春夏季：星期一至星期五09：00-17：00（法定节假日除外，中午不间断服务）\n秋冬季：星...
# 17     春夏季：星期一至星期五09：00-17：00（法定节假日除外，中午不间断服务）\n秋冬季：星...
# 18     春夏季：星期一至星期五09：00-17：00（法定节假日除外，中午不间断服务）\n秋冬季：星...
# 19     春夏季：星期一至星期五09：00-17：00（法定节假日除外，中午不间断服务）\n秋冬季：星...
# 20     春夏季：星期一至星期五09：00-17：00（法定节假日除外，中午不间断服务）\n秋冬季：星...
# ...                                                  ...
# 35095  夏令时上午8:30—11:30，下午13:00—17:00；冬令时上午8:30—11:30，...
# 35193  春夏季：星期一至星期五08：30-16：30（法定节假日除外，中午不间断服务） \n秋冬季：...
# 35370  春夏季：星期一至星期五09：00-17：00（法定节假日除外，中午不间断服务）秋冬季：星期一...
# 35546  春夏季：星期一至星期五08：30-16：30（法定节假日除外，中午不间断服务） \n秋冬季：...
# 35867  春夏季：星期一至星期五：8：30-16：30（法定节假日除外，中午不间断服务）\n秋冬季：星...
#
#                                咨询方式  \
# 16      0431—88779717；0431—88779716
# 17      0431—88779717；0431—88779716
# 18      0431—88779717；0431—88779716
# 19      0431—88779717；0431—88779716
# 20      0431—88779717；0431—88779716
# ...                             ...
# 35095  0431-80889804\n0431-89682700
# 35193                0431-87141008。
# 35370                 0431_89991069
# 35546            0431-0431-81188336
# 35867                    0431-12333
#
#                                                     材料名称   情形   是否合法
# 16            现存《事业单位法人证书》^事业单位法人证书补领申请书^原《事业单位法人证书》作废公告  NaN  False
# 17     原法定代表人行政免职文件^事业单位法人变更登记申请书^事业单位法人印鉴印模留存备案表^事业单...  NaN  False
# 18     事业单位法人开办资金确认证明（变更、重新申领专用）^《事业单位法人证书》正副本^资产负债表^...  NaN  False
# 19     事业单位法人设立（备案）登记申请书^资质认可证明或执业许可证明^事业单位法定代表人登记申请表...  NaN  False
# 20               《事业单位法人证书》正副本^经费来源改变的证明文件^事业单位法人变更登记申请书  NaN  False
# ...                                                  ...  ...    ...
# 35095                                                NaN  NaN  False
# 35193                                                身份证  NaN  False
# 35370                                                NaN  NaN  False
# 35546                                                NaN  NaN  False
# 35867                                                身份证  NaN  False
#
# [5545 rows x 15 columns]

# %%
# 按 "主项名称" 和 "子项名称" 分组，并统计每组的业务办理项数量
result = df.groupby(['主项名称', '子项名称']).size().reset_index(
    name='业务办理项数量').sort_values('业务办理项数量', ascending=False)

print(result)
# Out:
#                  主项名称                      子项名称  业务办理项数量
# 178            就业信息服务                  就业政策法规咨询     2472
# 375  职业介绍、职业指导和创业开业指导                      职业介绍     1724
# 182            就业失业登记                      就业登记      695
# 4             不动产统一登记                   建设用地使用权      661
# 376  职业介绍、职业指导和创业开业指导                      职业指导      377
# ..                ...                       ...      ...
# 404    计算机技术与软件专业技术资格  计算机技术与软件专业技术资格（水平）考试中级申报        1
# 405    计算机技术与软件专业技术资格  计算机技术与软件专业技术资格（水平）考试初级申报        1
# 406    计算机技术与软件专业技术资格  计算机技术与软件专业技术资格（水平）考试高级申报        1
# 408            辐射安全许可                     许可证变更        1
# 12         专业技术人员管理服务                   博士后设站申报        1
#
# [432 rows x 3 columns]

# %%
# 按 "子项名称" 分组，统计每组的记录数（包括重复项和空值）
result = df.groupby('子项名称').size().reset_index(
    name='业务办理项数量').sort_values('业务办理项数量', ascending=False)

print(result)
# Out:
#                     子项名称  业务办理项数量
# 176             就业政策法规咨询     2472
# 352                 职业介绍     1724
# 177                 就业登记      695
# 210              建设用地使用权      661
# 358                 职业指导      377
# ..                   ...      ...
# 67       保安服务公司法定代表人变更许可        1
# 68            保安服务公司设立许可        1
# 24   举办Ⅱ级（含）以上大型焰火燃放活动许可        1
# 34           二级建造师执业资格认定        1
# 17          中等职业学校教师资格认定        1
#
# [430 rows x 2 columns]

# %%
import pandas as pd

# 假设你的数据框名为 df
# 假设业务办理项的列名为"业务办理项名称"（请替换为实际列名）

# 方法：按"子项名称"分组，对"业务办理项名称"进行不重复计数
result = df.groupby('子项名称')['业务办理项名称'].nunique().reset_index(name='不重复业务办理项数量') \
    .sort_values('不重复业务办理项数量', ascending=False) \
    .reset_index(drop=True)

print(result)
# Out:
#                子项名称  不重复业务办理项数量
# 0           建设用地使用权          60
# 1         勘察设计注册工程师          33
# 2      户口迁移审批（县级权限）          21
# 3             抵押权登记          18
# 4              查封登记          16
# ..              ...         ...
# 425      企业年金方案终止备案           1
# 426  企业年金方案重要条款变更备案           1
# 427        企业社会保险登记           1
# 428       企业经济性裁员报告           1
# 429    一次性工伤医疗补助金申请           1
#
# [430 rows x 2 columns]

# %%
# 按 "主项名称" 和 "子项名称" 分组，并统计每组的业务办理项数量
# result = df.groupby(['主项名称']).size().reset_index(
#     name='业务办理项数量').sort_values('业务办理项数量', ascending=False)
result = df.groupby('主项名称')['业务办理项名称'].nunique().reset_index(name='不重复业务办理项数量') \
    .sort_values('不重复业务办理项数量', ascending=False) \
    .reset_index(drop=True)
print(result)
# Out:
#                   主项名称  不重复业务办理项数量
# 0              不动产统一登记         145
# 1         专业技术人员资格考试报名          84
# 2          住房公积金归集业务审批          49
# 3          职工提取住房公积金审批          39
# 4               企业登记注册          30
# ...                ...         ...
# 1046     防震减灾科普教育基地的认定           1
# 1047     防震减灾科普示范学校的认定           1
# 1048          附加税（费）申报           1
# 1049     限制进出口货物的许可证审批           1
# 1050  限售股转让所得个人所得税清算申报           1
#
# [1051 rows x 2 columns]

# %%
result = df.groupby(['主项名称', '子项名称'])['业务办理项名称'].nunique().reset_index(name='不重复业务办理项数量') \
    .sort_values('不重复业务办理项数量', ascending=False) \
    .reset_index(drop=True)
print(result)
# Out:
#                        主项名称                    子项名称  不重复业务办理项数量
# 0                   不动产统一登记                 建设用地使用权          60
# 1              专业技术人员资格考试报名               勘察设计注册工程师          33
# 2                    户口迁移审批            户口迁移审批（县级权限）          21
# 3                   不动产统一登记                   抵押权登记          18
# 4                   不动产统一登记                    查封登记          16
# ..                      ...                     ...         ...
# 427          事业单位工作人员奖励审核备案          事业单位工作人员奖励审核备案           1
# 428      事业单位（机关工勤）人员调动审核备案      事业单位（机关工勤）人员调动审核备案           1
# 429              专业技术人员管理服务                 博士后设站申报           1
# 430  企业实行不定时工作制和综合计算工时工作制审批  企业实行不定时工作制和综合计算工时工作制审批           1
# 431                  工伤保险服务              异地居住就医申请确认           1
#
# [432 rows x 3 columns]

# %%
san_dao_data = df[df['区划名称'] == '三道村']
print(san_dao_data[['区划名称', '上级区划名称']])
# Out:
#       区划名称                    上级区划名称
# 28982  三道村           环城乡,榆树市,长春市,吉林省
# 28984  三道村           环城乡,榆树市,长春市,吉林省
# 28985  三道村           环城乡,榆树市,长春市,吉林省
# 29297  三道村           同太乡,德惠市,长春市,吉林省
# 29299  三道村           同太乡,德惠市,长春市,吉林省
# 29888  三道村           于家镇,榆树市,长春市,吉林省
# 29997  三道村         莽卡满族乡,九台区,长春市,吉林省
# 29998  三道村         莽卡满族乡,九台区,长春市,吉林省
# 30684  三道村           于家镇,榆树市,长春市,吉林省
# 32054  三道村  东方广场街道,长春经济技术开发区,长春市,吉林省
# 32055  三道村  东方广场街道,长春经济技术开发区,长春市,吉林省
# 32116  三道村  东方广场街道,长春经济技术开发区,长春市,吉林省
# 32240  三道村           于家镇,榆树市,长春市,吉林省
# 32323  三道村         莽卡满族乡,九台区,长春市,吉林省

# %%
# 选择需要的列并去重
unique_districts = df[['区划名称', '地区层级', '上级区划名称']].drop_duplicates()

# 保存到新的Excel文件
output_file = '不重复区划数据.xlsx'
unique_districts.to_excel(output_file, index=False)

print(f"已保存不重复区划数据到: {output_file}")
print(f"共保存 {len(unique_districts)} 条不重复记录")
# Out:
# 已保存不重复区划数据到: 不重复区划数据.xlsx
# 共保存 2833 条不重复记录
